# %% [markdown]
# ### Dependent Libraries

# %%
import pandas as pd
import csv
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords

# %% [markdown]
# ### Preprocess Input Data

# %%
df = pd.read_csv('./cve_data_description_only.csv')
df.dropna(inplace=True)

cve_arr = []

for cve in df['Description']:
    if '**' not in cve:
        cve_arr.append(cve)

#remove duplicates
cve_arr = list(set(cve_arr))

# %% [markdown]
# ### Summarization
#
# 1. clean raw text(remove numbers, puncutation, etc)
# 2. split clean text into individual sentences
# 3. tokenize each sentence into respective words
# 4. convert tokenize sentences into sentence vectors(sequence of word vectors or average of word vectors in a sentence)
# 5. create similarity matrix(# of sentences by # of sentences) -> similarity between 2 sentence vectors(consine similarity)
# 6. create a graph out of the similar matrix(nodes: sentences, edges: similarity)
# 7. rank each node(page ranking algorithm) to score the important of a sentence
# 8. output the top 'k' sentences
#
# ### Keyword Extraction
#
# 1. The same process as Summarization except we are picking the most important words instead of the most important sentences

# %%
keywords_arr = []

for i in range(len(cve_arr)):
    cve = cve_arr[i]
    
    #attempt to summarize the input cve
    try:
        summary = summarize(cve, ratio=0.2)
    except:
        #input was only one sentence
        summary = cve
        
    raw_keywords = keywords(cve, words=5, split=True)
    summary_keywords = keywords(summary, words=5, lemmatize=True, split=True)
    
    if i < 50:
        print('raw:',cve)
        print('raw keywords:',raw_keywords)
        print('summary:', summary)
        print('summary keywords:', summary_keywords)
        print('------------------------------------')
        
    keywords_arr.append(str(raw_keywords))
# Out:
# raw: Multiple unspecified vulnerabilities in the kernel in Sun Solaris 8 through 10 allow local users to cause a denial of service (panic), related to the support for retrieval of kernel statistics, and possibly related to the sfmmu_mlspl_enter or sfmmu_mlist_enter functions.
# raw keywords: ['unspecified', 'local', 'panic related', 'functions']
# summary: Multiple unspecified vulnerabilities in the kernel in Sun Solaris 8 through 10 allow local users to cause a denial of service (panic), related to the support for retrieval of kernel statistics, and possibly related to the sfmmu_mlspl_enter or sfmmu_mlist_enter functions.
# summary keywords: ['local', 'unspecified', 'panic related', 'statistics']
# ------------------------------------
# raw: Multiple directory traversal vulnerabilities in Splunk 4.x before 4.2.5 allow remote authenticated users to read arbitrary files via a .. (dot dot) in a URI to (1) Splunk Web or (2) the Splunkd HTTP Server, aka SPL-45243.
# raw keywords: ['arbitrary', 'remote authenticated', 'directory traversal']
# summary:
# summary keywords: []
# ------------------------------------
# raw: Multiple cross-site scripting (XSS) vulnerabilities in PHD Help Desk 1.43 allow remote attackers to inject arbitrary web script or HTML via (1) the PATH_INFO to area.php; the (2) pagina, (3) sentido, (4) q_registros, and (5) orden parameters to area.php; (6) the q_registros parameter to solic_display.php; (7) the PATH_INFO to area_list.php; (8) the q_registros parameter to area_list.php; (9) the PATH_INFO to atributo.php; the (10) pagina, (11) q_registros, and (12) orden parameters to atributo_list.php; (13) an arbitrary parameter name beginning with "sentido" to atributo_list.php; and (14) the PATH_INFO to caso_insert.php.  NOTE: the provenance of this information is unknown; the details are obtained solely from third party information.
# raw keywords: ['scripting', 'script', 'arbitrary', 'parameters', 'parameter', 'q_registros']
# summary:
# summary keywords: []
# ------------------------------------
# raw: An information disclosure vulnerability exists when the Windows kernel improperly handles objects in memory, aka "Windows Kernel Information Disclosure Vulnerability." This affects Windows 7, Windows Server 2012 R2, Windows RT 8.1, Windows Server 2008, Windows Server 2012, Windows 8.1, Windows Server 2008 R2. This CVE ID is unique from CVE-2018-8477, CVE-2018-8621.
# raw keywords: ['windows kernel', 'handles', 'disclosure vulnerability']
# summary:
# summary keywords: []
# ------------------------------------
# raw: The sell function of a smart contract implementation for MyToken, an Ethereum token, has an integer overflow in which "amount * sellPrice" can be zero, consequently reducing a seller's assets.
# raw keywords: ['contract', 'consequently', 'ethereum', 'token', 'function']
# summary: The sell function of a smart contract implementation for MyToken, an Ethereum token, has an integer overflow in which "amount * sellPrice" can be zero, consequently reducing a seller's assets.
# summary keywords: ['contract', 'consequently', 'integer overflow', 'sell']
# ------------------------------------
# raw: Buffer overflow in the getauthfromURL function in httpget.c in mpg123 pre0.59s and mpg123 0.59r could allow remote attackers or local users to execute arbitrary code via an mp3 file that contains a long string before the @ (at sign) in a URL.
# raw keywords: ['remote', 'arbitrary', 'getauthfromurl function', 'mpg']
# summary: Buffer overflow in the getauthfromURL function in httpget.c in mpg123 pre0.59s and mpg123 0.59r could allow remote attackers or local users to execute arbitrary code via an mp3 file that contains a long string before the @ (at sign) in a URL.
# summary keywords: ['arbitrary', 'remote', 'pre', 'buffer', 'mpg']
# ------------------------------------
# raw: Buffer overflow in the vararg functions in ldo.c in Lua 5.1 through 5.2.x before 5.2.3 allows context-dependent attackers to cause a denial of service (crash) via a small number of arguments to a function with a large number of fixed arguments.
# raw keywords: ['number', 'context', 'service', 'functions', 'function']
# summary: Buffer overflow in the vararg functions in ldo.c in Lua 5.1 through 5.2.x before 5.2.3 allows context-dependent attackers to cause a denial of service (crash) via a small number of arguments to a function with a large number of fixed arguments.
# summary keywords: ['number', 'context', 'fixed', 'arguments']
# ------------------------------------
# raw: The key_user_lookup function in security/keys/key.c in Linux kernel 2.6.10 to 2.6.11.8 may allow attackers to cause a denial of service (oops) via SMP.
# raw keywords: ['allow attackers', 'linux kernel']
# summary: The key_user_lookup function in security/keys/key.c in Linux kernel 2.6.10 to 2.6.11.8 may allow attackers to cause a denial of service (oops) via SMP.
# summary keywords: ['linux kernel', 'service', 'oops']
# ------------------------------------
# raw: Off-by-one error in monitor.c in Qemu 0.9.1 might make it easier for remote attackers to guess the VNC password, which is limited to seven characters where eight was intended.
# raw keywords: ['seven characters', 'remote attackers', 'password']
# summary: Off-by-one error in monitor.c in Qemu 0.9.1 might make it easier for remote attackers to guess the VNC password, which is limited to seven characters where eight was intended.
# summary keywords: ['seven characters', 'vnc', 'password', 'remote']
# ------------------------------------
# raw: Cross-site scripting (XSS) vulnerability in start_form() of CGI.pm allows remote attackers to insert web script via a URL that is fed into the form's action parameter.
# raw keywords: ['scripting', 'remote', 'web script', 'xss']
# summary: Cross-site scripting (XSS) vulnerability in start_form() of CGI.pm allows remote attackers to insert web script via a URL that is fed into the form's action parameter.
# summary keywords: ['remote', 'web script', 'xss']
# ------------------------------------
# raw: libsecurity in Apple Mac OS X before 10.7.4 does not properly restrict the length of RSA keys within X.509 certificates, which makes it easier for remote attackers to defeat cryptographic protection mechanisms by conducting a spoofing or network-sniffing attack during communication with a site that uses a short key.
# raw keywords: ['keys', 'key', 'cryptographic protection', 'attackers', 'attack']
# summary: libsecurity in Apple Mac OS X before 10.7.4 does not properly restrict the length of RSA keys within X.509 certificates, which makes it easier for remote attackers to defeat cryptographic protection mechanisms by conducting a spoofing or network-sniffing attack during communication with a site that uses a short key.
# summary keywords: ['key', 'attack', 'cryptographic protection']
# ------------------------------------
# raw: A cross-site scripting (XSS) vulnerability in the JOC Cockpit component of SOS JobScheduler 1.11 and 1.13.2 allows attackers to inject arbitrary web script or HTML via JSON properties available from the REST API.
# raw keywords: ['scripting', 'script', 'properties', 'cockpit', 'arbitrary', 'xss']
# summary: A cross-site scripting (XSS) vulnerability in the JOC Cockpit component of SOS JobScheduler 1.11 and 1.13.2 allows attackers to inject arbitrary web script or HTML via JSON properties available from the REST API.
# summary keywords: ['script', 'properties', 'cockpit', 'arbitrary', 'xss']
# ------------------------------------
# raw: Buffer overflow in the Configuration Checker (ConfigChk) ActiveX control in VSCnfChk.dll 2.0.0.2 for Verisign Managed PKI Service, Secure Messaging for Microsoft Exchange, and Go Secure! allows remote attackers to execute arbitrary code via long arguments to the VerCompare method.
# raw keywords: ['secure', 'arbitrary', 'activex', 'checker', 'configchk']
# summary:
# summary keywords: []
# ------------------------------------
# raw: Unspecified vulnerability in the Java Embedding Plugin (JEP) in Mozilla Firefox before 3.5.19 and 3.6.x before 3.6.17, and SeaMonkey before 2.0.14, on Mac OS X allows remote attackers to bypass intended access restrictions via unknown vectors.
# raw keywords: ['remote', 'plugin', 'embedding', 'intended access']
# summary: Unspecified vulnerability in the Java Embedding Plugin (JEP) in Mozilla Firefox before 3.5.19 and 3.6.x before 3.6.17, and SeaMonkey before 2.0.14, on Mac OS X allows remote attackers to bypass intended access restrictions via unknown vectors.
# summary keywords: ['remote', 'embedding', 'plugin', 'intended access']
# ------------------------------------
# raw: Unspecified vulnerability in PeopleTools in Oracle PeopleSoft Enterprise 8.22.14, 8.47.12, and 8.48.08 has unknown impact and attack vectors, aka PSE01.
# raw keywords: ['peoplesoft', 'vectors aka', 'unspecified vulnerability']
# summary: Unspecified vulnerability in PeopleTools in Oracle PeopleSoft Enterprise 8.22.14, 8.47.12, and 8.48.08 has unknown impact and attack vectors, aka PSE01.
# summary keywords: ['peoplesoft', 'vectors aka', 'unspecified vulnerability']
# ------------------------------------
# raw: An exploitable operating system command injection exists in the Linksys ESeries line of routers (Linksys E1200 Firmware Version 2.0.09 and Linksys E2500 Firmware Version 3.0.04). Specially crafted entries to network configuration information can cause execution of arbitrary system commands, resulting in full control of the device. An attacker can send an authenticated HTTP request to trigger this vulnerability. Data entered into the 'Domain Name' input field through the web portal is submitted to apply.cgi as the value to the 'wan_domain' POST parameter. The wan_domain data goes through the nvram_set process described above. When the 'preinit' binary receives the SIGHUP signal it enters a code path that calls a function named 'set_host_domain_name' from its libshared.so shared object.
# raw keywords: ['data', 'binary', 'http', 'process', 'named']
# summary: The wan_domain data goes through the nvram_set process described above.
# summary keywords: ['nvram_set process', 'wan_domain data goes']
# ------------------------------------
# raw: Multiple buffer overflows in Adobe Photoshop CS4 before 11.0.2 allow user-assisted remote attackers to execute arbitrary code via a crafted (1) .ASL, (2) .ABR, or (3) .GRD file.
# raw keywords: ['buffer', 'asl', 'arbitrary', 'user remote']
# summary: Multiple buffer overflows in Adobe Photoshop CS4 before 11.0.2 allow user-assisted remote attackers to execute arbitrary code via a crafted (1) .ASL, (2) .ABR, or (3) .GRD file.
# summary keywords: ['asl', 'buffer', 'arbitrary', 'user remote']
# ------------------------------------
# raw: JWT.php in F21 JWT before 2.0 allows remote attackers to bypass signature verification via crafted tokens.
# raw keywords: ['signature', 'remote', 'crafted', 'tokens', 'jwt']
# summary: JWT.php in F21 JWT before 2.0 allows remote attackers to bypass signature verification via crafted tokens.
# summary keywords: ['remote', 'signature', 'crafted', 'tokens', 'jwt']
# ------------------------------------
# raw: Cross-site scripting (XSS) vulnerability in Help.aspx in mojoPortal version 2.5.0.0 allows remote attackers to inject arbitrary web script or HTML via the helpkey parameter. Exploitation requires authenticated reflected cross-site scripting for user accounts assigned either the "Administrators" or "Content Administrators" role.
# raw keywords: ['scripting', 'script', 'accounts', 'administrators', 'version', 'remote']
# summary:
# summary keywords: []
# ------------------------------------
# raw: A vulnerability exists in Docker before 1.2 via container names, which may collide with and override container IDs.
# raw keywords: ['container', 'vulnerability exists', 'ids', 'override']
# summary: A vulnerability exists in Docker before 1.2 via container names, which may collide with and override container IDs.
# summary keywords: ['container', 'vulnerability exists', 'ids', 'override']
# ------------------------------------
# raw: Denial of service in Ascend and 3com routers, which can be rebooted by sending a zero length TCP option.
# raw keywords: ['tcp', 'routers', 'com', 'zero length']
# summary: Denial of service in Ascend and 3com routers, which can be rebooted by sending a zero length TCP option.
# summary keywords: ['tcp', 'routers', 'zero length', 'com']
# ------------------------------------
# raw: Multiple use-after-free vulnerabilities in modules/screen_orientation/ScreenOrientationController.cpp in Blink, as used in Google Chrome before 39.0.2171.65, allow remote attackers to cause a denial of service or possibly have unspecified other impact via vectors that trigger improper handling of a detached frame, related to the (1) lock and (2) unlock methods.
# raw keywords: ['frame', 'improper', 'remote']
# summary: Multiple use-after-free vulnerabilities in modules/screen_orientation/ScreenOrientationController.cpp in Blink, as used in Google Chrome before 39.0.2171.65, allow remote attackers to cause a denial of service or possibly have unspecified other impact via vectors that trigger improper handling of a detached frame, related to the (1) lock and (2) unlock methods.
# summary keywords: ['remote', 'frame', 'improper']
# ------------------------------------
# raw: Unspecified vulnerability in the PeopleSoft Enterprise PeopleTools component in Oracle PeopleSoft Products 8.54 allows remote attackers to affect integrity via vectors related to PIA Core Technology.
# raw keywords: ['peoplesoft', 'core', 'peopletools', 'allows remote']
# summary: Unspecified vulnerability in the PeopleSoft Enterprise PeopleTools component in Oracle PeopleSoft Products 8.54 allows remote attackers to affect integrity via vectors related to PIA Core Technology.
# summary keywords: ['peoplesoft', 'core', 'peopletools', 'allows remote']
# ------------------------------------
# raw: Apache Tomcat before 5.x allows remote attackers to cause a denial of service (application crash) via a crafted AJP12 packet to TCP port 8007.
# raw keywords: ['application', 'remote', 'ajp', 'tcp port']
# summary: Apache Tomcat before 5.x allows remote attackers to cause a denial of service (application crash) via a crafted AJP12 packet to TCP port 8007.
# summary keywords: ['application', 'ajp', 'remote', 'apache', 'tcp']
# ------------------------------------
# raw: Multiple heap-based buffer overflows in ovsessionmgr.exe in HP OpenView Network Node Manager (OV NNM) 7.01, 7.51, and 7.53 allow remote attackers to execute arbitrary code via a long (1) userid or (2) passwd parameter to ovlogin.exe.
# raw keywords: ['remote', 'arbitrary', 'network', 'node']
# summary: Multiple heap-based buffer overflows in ovsessionmgr.exe in HP OpenView Network Node Manager (OV NNM) 7.01, 7.51, and 7.53 allow remote attackers to execute arbitrary code via a long (1) userid or (2) passwd parameter to ovlogin.exe.
# summary keywords: ['remote', 'arbitrary', 'node', 'network']
# ------------------------------------
# raw: SQL injection vulnerability in index.php in Plague News System 0.6 and earlier allows remote attackers to execute arbitrary SQL commands via the cid parameter.
# raw keywords: ['sql injection', 'allows remote', 'arbitrary']
# summary: SQL injection vulnerability in index.php in Plague News System 0.6 and earlier allows remote attackers to execute arbitrary SQL commands via the cid parameter.
# summary keywords: ['sql injection', 'allows remote', 'arbitrary']
# ------------------------------------
# raw: SQL injection vulnerability in firma.php in Bartels Schone ConPresso 4.0.7 allows remote attackers to execute arbitrary SQL commands via the id parameter.
# raw keywords: ['sql injection', 'remote', 'schone', 'arbitrary']
# summary: SQL injection vulnerability in firma.php in Bartels Schone ConPresso 4.0.7 allows remote attackers to execute arbitrary SQL commands via the id parameter.
# summary keywords: ['sql injection', 'remote', 'schone', 'arbitrary']
# ------------------------------------
# raw: Cross-site scripting (XSS) vulnerability in admin.jcomments.php in the JoomlaTune JComments (com_jcomments) component 2.1.0.0 for Joomla! allows remote authenticated users to inject arbitrary web script or HTML via the name parameter to index.php.
# raw keywords: ['jcomments', 'scripting', 'script', 'allows remote authenticated']
# summary:
# summary keywords: []
# ------------------------------------
# raw: Cooper Power Systems Cybectec DNP3 Master OPC Server allows remote attackers to cause a denial of service (unhandled exception and process crash) via unspecified vectors.
# raw keywords: ['unhandled', 'power', 'allows remote', 'systems']
# summary: Cooper Power Systems Cybectec DNP3 Master OPC Server allows remote attackers to cause a denial of service (unhandled exception and process crash) via unspecified vectors.
# summary keywords: ['unhandled', 'power', 'allows remote', 'systems']
# ------------------------------------
# raw: Citrix Workspace App before 1904 for Windows has Incorrect Access Control.
# raw keywords: ['access', 'workspace', 'incorrect', 'control', 'citrix']
# summary: Citrix Workspace App before 1904 for Windows has Incorrect Access Control.
# summary keywords: ['workspace', 'access', 'app', 'citrix', 'incorrect']
# ------------------------------------
# raw: The animate-it plugin before 2.3.6 for WordPress has CSRF in edsanimate.php.
# raw keywords: ['edsanimate']
# summary: The animate-it plugin before 2.3.6 for WordPress has CSRF in edsanimate.php.
# summary keywords: ['edsanimate']
# ------------------------------------
# raw: Liesbeth base CMS stores sensitive information under the web root with insufficient access control, which allows remote attackers to download an include file containing account credentials via a direct request for config.inc.
# raw keywords: ['access', 'remote', 'file', 'account', 'sensitive']
# summary: Liesbeth base CMS stores sensitive information under the web root with insufficient access control, which allows remote attackers to download an include file containing account credentials via a direct request for config.inc.
# summary keywords: ['remote', 'access', 'account', 'file', 'sensitive']
# ------------------------------------
# raw: The spotim-comments plugin before 4.0.4 for WordPress has multiple XSS issues.
# raw keywords: ['xss', 'issues', 'multiple', 'spotim']
# summary: The spotim-comments plugin before 4.0.4 for WordPress has multiple XSS issues.
# summary keywords: ['xss', 'spotim plugin', 'issues']
# ------------------------------------
# raw: Multiple memory leaks in kadmin/server/server_stubs.c in kadmind in MIT Kerberos 5 (aka krb5) before 1.13.4 and 1.14.x before 1.14.1 allow remote authenticated users to cause a denial of service (memory consumption) via a request specifying a NULL principal name.
# raw keywords: ['memory', 'aka', 'authenticated', 'kerberos']
# summary: Multiple memory leaks in kadmin/server/server_stubs.c in kadmind in MIT Kerberos 5 (aka krb5) before 1.13.4 and 1.14.x before 1.14.1 allow remote authenticated users to cause a denial of service (memory consumption) via a request specifying a NULL principal name.
# summary keywords: ['memory', 'remote authenticated', 'aka']
# ------------------------------------
# raw: Stack-based buffer overflow in FTPShell Client 4.1 RC2 allows remote FTP servers to execute arbitrary code via a long response to a PASV command.
# raw keywords: ['arbitrary', 'remote', 'buffer', 'ftp']
# summary: Stack-based buffer overflow in FTPShell Client 4.1 RC2 allows remote FTP servers to execute arbitrary code via a long response to a PASV command.
# summary keywords: ['arbitrary', 'buffer', 'ftp', 'remote']
# ------------------------------------
# raw: Unspecified vulnerability in the Oracle WebCenter Content component in Oracle Fusion Middleware 7.5.2, 10.1.3.5.1, 11.1.1.3, 11.1.1.4, and 11.1.1.5 allows remote attackers to affect confidentiality and integrity via unknown vectors related to Search.
# raw keywords: ['remote', 'vectors', 'content', 'fusion', 'webcenter']
# summary: Unspecified vulnerability in the Oracle WebCenter Content component in Oracle Fusion Middleware 7.5.2, 10.1.3.5.1, 11.1.1.3, 11.1.1.4, and 11.1.1.5 allows remote attackers to affect confidentiality and integrity via unknown vectors related to Search.
# summary keywords: ['vectors', 'remote', 'fusion', 'content', 'webcenter']
# ------------------------------------
# raw: Unspecified vulnerability in the Java Runtime Environment (JRE) component in Oracle Java SE 7 Update 17 and earlier, and OpenJDK 6 and 7, allows remote attackers to affect confidentiality, integrity, and availability via unknown vectors related to HotSpot.  NOTE: the previous information is from the April 2013 CPU. Oracle has not commented on claims from another vendor that this issue is related to incorrect MethodHandle lookups, which allows remote attackers to bypass Java sandbox restrictions.
# raw keywords: ['java', 'vectors', 'confidentiality', 'remote', 'methodhandle']
# summary:
# summary keywords: []
# ------------------------------------
# raw: An issue was discovered in Zoho ManageEngine OpManager in builds before 14310. One can bypass the user password requirement and execute commands on the server. The "username+'@opm' string is used for the password. For example, if the username is admin, the password is admin@opm.
# raw keywords: ['manageengine', 'password', 'execute commands']
# summary:
# summary keywords: []
# ------------------------------------
# raw: This vulnerability allows local attackers to escalate privileges on affected installations of Parallels Desktop 15.1.3-47255. An attacker must first obtain the ability to execute low-privileged code on the target system in order to exploit this vulnerability. The specific flaw exists within the handler for HOST_IOCTL_SET_KERNEL_SYMBOLS in the prl_hypervisor kext. The issue results from the lack of proper validation of a user-supplied value prior to dereferencing it as a pointer. An attacker can leverage this vulnerability to escalate privileges and execute code in the context of the kernel. Was ZDI-CAN-10519.
# raw keywords: ['privileges', 'flaw', 'allows local', 'value']
# summary: An attacker can leverage this vulnerability to escalate privileges and execute code in the context of the kernel.
# summary keywords: ['escalate privileges', 'execute code']
# ------------------------------------
# raw: Server-side request forgery (SSRF) vulnerability in the documentconverter component in Open-Xchange (OX) AppSuite before 7.4.2-rev10 and 7.6.x before 7.6.0-rev10 allows remote attackers to trigger requests to arbitrary servers and embed arbitrary images via a URL in an embedded image in a Text document, which is not properly handled by the image preview.
# raw keywords: ['images', 'image', 'arbitrary', 'allows remote', 'ssrf']
# summary: Server-side request forgery (SSRF) vulnerability in the documentconverter component in Open-Xchange (OX) AppSuite before 7.4.2-rev10 and 7.6.x before 7.6.0-rev10 allows remote attackers to trigger requests to arbitrary servers and embed arbitrary images via a URL in an embedded image in a Text document, which is not properly handled by the image preview.
# summary keywords: ['image', 'arbitrary', 'allows remote', 'ssrf']
# ------------------------------------
# raw: Unknown vulnerability in SandSurfer before 1.7.0 allows remote attackers to gain access as a logged-in user.
# raw keywords: ['remote', 'gain access', 'unknown vulnerability']
# summary: Unknown vulnerability in SandSurfer before 1.7.0 allows remote attackers to gain access as a logged-in user.
# summary keywords: ['remote', 'unknown vulnerability', 'gain access']
# ------------------------------------
# raw: Limbo CMS 1.0.4.2 and earlier allows remote attackers to obtain the installation path of the application via a direct request to (1) doc.inc.php, (2) element.inc.php, and (3) node.inc.php, which leaks the path in an error message.
# raw keywords: ['allows remote', 'limbo', 'cms', 'error']
# summary: Limbo CMS 1.0.4.2 and earlier allows remote attackers to obtain the installation path of the application via a direct request to (1) doc.inc.php, (2) element.inc.php, and (3) node.inc.php, which leaks the path in an error message.
# summary keywords: ['allows remote', 'path', 'element', 'error']
# ------------------------------------
# raw: Phex before 2.8.6 allows remote attackers to cause a denial of service (application hang) by initiating multiple chat requests to a single user and then logging off.
# raw keywords: ['remote', 'application', 'multiple chat', 'user']
# summary: Phex before 2.8.6 allows remote attackers to cause a denial of service (application hang) by initiating multiple chat requests to a single user and then logging off.
# summary keywords: ['remote', 'application', 'multiple chat', 'single']
# ------------------------------------
# raw: Emerson Process Management ROC800 RTU with software 3.50 and earlier, DL8000 RTU with software 2.30 and earlier, and ROC800L RTU with software 1.20 and earlier allows remote attackers to execute arbitrary commands via a TCP replay attack.
# raw keywords: ['arbitrary', 'roc', 'process', 'allows', 'replay']
# summary: Emerson Process Management ROC800 RTU with software 3.50 and earlier, DL8000 RTU with software 2.30 and earlier, and ROC800L RTU with software 1.20 and earlier allows remote attackers to execute arbitrary commands via a TCP replay attack.
# summary keywords: ['arbitrary', 'process', 'roc', 'allows', 'replay']
# ------------------------------------
# raw: Unspecified vulnerability in Movable Type Pro and Community Solution 4.x before 4.24 has unknown impact and attack vectors, possibly related to the password recovery mechanism.
# raw keywords: ['recovery', 'type', 'vectors possibly', 'solution']
# summary: Unspecified vulnerability in Movable Type Pro and Community Solution 4.x before 4.24 has unknown impact and attack vectors, possibly related to the password recovery mechanism.
# summary keywords: ['type', 'recovery', 'vectors possibly', 'unknown']
# ------------------------------------
# raw: IBM Connections 5.0, 5.5, and 6.0 could allow a remote attacker to conduct phishing attacks, using an open redirect attack. By persuading a victim to visit a specially-crafted Web site, a remote attacker could exploit this vulnerability to spoof the URL displayed to redirect a user to a malicious Web site that would appear to be trusted. This could allow the attacker to obtain highly sensitive information or conduct further attacks against the victim. IBM X-Force ID: 135521.
# raw keywords: ['web', 'attacker', 'attacks', 'attack', 'ibm', 'highly sensitive']
# summary:
# summary keywords: []
# ------------------------------------
# raw: An issue was discovered in certain Apple products. iOS before 10.3 is affected. macOS before 10.12.4 is affected. tvOS before 10.2 is affected. watchOS before 3.2 is affected. The issue involves the "Security" component. It allows attackers to execute arbitrary code in a privileged context or cause a denial of service (buffer overflow) via a crafted app.
# raw keywords: ['affected', 'buffer', 'arbitrary', 'products', 'apple']
# summary: watchOS before 3.2 is affected.
# summary keywords: []
# ------------------------------------
# raw: Quest DR Series Disk Backup software version before 4.0.3.1 allows command injection (issue 27 of 46).
# raw keywords: ['command injection', 'disk', 'backup software']
# summary: Quest DR Series Disk Backup software version before 4.0.3.1 allows command injection (issue 27 of 46).
# summary keywords: ['command injection', 'disk', 'backup software']
# ------------------------------------
# raw: /filemanager/ajax_calls.php in tecrail Responsive FileManager before 9.13.4 uses external input to construct a pathname that should be within a restricted directory, but it does not properly neutralize get_file sequences such as ".." that can resolve to a location that is outside of that directory, aka Directory Traversal.
# raw keywords: ['directory', 'external', 'neutralize get_file']
# summary: /filemanager/ajax_calls.php in tecrail Responsive FileManager before 9.13.4 uses external input to construct a pathname that should be within a restricted directory, but it does not properly neutralize get_file sequences such as ".." that can resolve to a location that is outside of that directory, aka Directory Traversal.
# summary keywords: ['directory', 'external', 'neutralize get_file']
# ------------------------------------
# raw: IBM Cloud App Management V2018.2.0, V2018.4.0, and V2018.4.1 could allow an attacker to obtain sensitive configuration information using a specially crafted HTTP request. IBM X-Force ID: 154283.
# raw keywords: ['sensitive configuration', 'crafted', 'app', 'http']
# summary:
# summary keywords: []
# ------------------------------------

# %%
fields = ['Description', 'Keywords']
output_data = []
for a,b in zip(cve_arr, keywords_arr):
    output_data.append([a,b])

with open('cve_keywords.csv', 'w') as f: 
      
    write = csv.writer(f) 
    write.writerow(fields) 
    write.writerows(output_data)
